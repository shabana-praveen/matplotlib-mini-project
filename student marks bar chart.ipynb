# %%
import matplotlib.pyplot as plt
students=["Sana","karan","Aman","Riya"]
marks=[80,40,50,90]
plt.title("Students Marks Analysis")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.bar(students,marks,width=0.4,color="skyblue",label="Student Marks")
plt.legend()
plt.show()
